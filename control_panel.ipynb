# %%
from clients.vecdb_client import VectorDBClient
import pandas as pd
import numpy as np
import json
import os
import config
from schemas.document import ArxivDocument
from utils.jsonl_utils import load_jsonl
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
points = load_jsonl(ArxivDocument, config.RAW_DATA / 'arxiv_data_cache.jsonl')

# %%
qd_client = VectorDBClient()
qd_client.delete_collection()
qd_client.make_collection()
qd_client.upsert_points(points)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 qd_client = VectorDBClient()
#       2 qd_client.delete_collection()
#       3 qd_client.make_collection()
#       4 qd_client.upsert_points(points)
#
# File c:\Workspace\arxiv_project\clients\vecdb_client.py:21, in VectorDBClient.__init__(self, dense_embedding_model_handle, sparse_embedding_model_handle, port_link)
#      13 """_summary_
#      14
#      15 Args:
#    (...)     18     port_link (_type_, optional): _description_. Defaults to "http://localhost:6333".
#      19 """
#      20 # self.client = QdrantClient(port_link)
# ---> 21 self.client = QdrantClient("qdrant", port=6333, api_key=os.environ["QDRANT_API_KEY"], url=os.environ["QDRANT_CLUSTER_ENDPOINT"])
#      22 # self.collection_list = self.client.get_collections()
#      23 self.dense_embedder = TextEmbedding(model_name=dense_embedding_model_handle)
#
# File c:\Workspace\arxiv_project\.venv\Lib\site-packages\qdrant_client\qdrant_client.py:116, in QdrantClient.__init__(self, location, url, port, grpc_port, prefer_grpc, https, api_key, prefix, timeout, host, path, force_disable_check_same_thread, grpc_options, auth_token_provider, cloud_inference, local_inference_batch_size, check_compatibility, pool_size, headers, **kwargs)
#     113 self._init_options.update({k: v for k, v in kwargs.items()})
#     115 if sum([param is not None for param in (location, url, host, path)]) > 1:
# --> 116     raise ValueError(
#     117         "Only one of <location>, <url>, <host> or <path> should be specified."
#     118     )
#     119 self._client: QdrantBase
#     121 if location == ":memory:":
#
# ValueError: Only one of <location>, <url>, <host> or <path> should be specified.
